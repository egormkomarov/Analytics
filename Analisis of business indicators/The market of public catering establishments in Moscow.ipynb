# %% [markdown]
# <h1>Анализ развлекательного приложения Procrastinate Pro+<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Анализ-исходных-данных" data-toc-modified-id="Анализ-исходных-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Анализ исходных данных</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Загрузка-исходных-данных" data-toc-modified-id="Загрузка-исходных-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка исходных данных</a></span><ul class="toc-item"><li><span><a href="#Описание-данных-таблицы-visits_info_short" data-toc-modified-id="Описание-данных-таблицы-visits_info_short-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Описание данных таблицы visits_info_short</a></span></li><li><span><a href="#Описание-данных-таблицы-orders_info_short" data-toc-modified-id="Описание-данных-таблицы-orders_info_short-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Описание данных таблицы orders_info_short</a></span></li><li><span><a href="#Описание-данных-таблицы-costs_info_short" data-toc-modified-id="Описание-данных-таблицы-costs_info_short-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Описание данных таблицы costs_info_short</a></span></li></ul></li><li><span><a href="#Приведение-названий-столбцов-и-типов-данных-к-требуемым" data-toc-modified-id="Приведение-названий-столбцов-и-типов-данных-к-требуемым-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Приведение названий столбцов и типов данных к требуемым</a></span><ul class="toc-item"><li><span><a href="#Преобразования-в-таблице-visits" data-toc-modified-id="Преобразования-в-таблице-visits-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Преобразования в таблице visits</a></span></li><li><span><a href="#Преобразования-в-таблице-orders" data-toc-modified-id="Преобразования-в-таблице-orders-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Преобразования в таблице orders</a></span></li><li><span><a href="#Преобразования-в-таблице-costs" data-toc-modified-id="Преобразования-в-таблице-costs-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Преобразования в таблице costs</a></span></li></ul></li><li><span><a href="#Проверка-на-пропущенные-значения-и-дубликаты" data-toc-modified-id="Проверка-на-пропущенные-значения-и-дубликаты-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Проверка на пропущенные значения и дубликаты</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование-каналов-привлечения-пользователей" data-toc-modified-id="Исследование-каналов-привлечения-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследование каналов привлечения пользователей</a></span></li><li><span><a href="#Исследование-популярности-устройств,-на-которых-установлено-приложение" data-toc-modified-id="Исследование-популярности-устройств,-на-которых-установлено-приложение-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследование популярности устройств, на которых установлено приложение</a></span></li><li><span><a href="#Исследование-географии-пользователей" data-toc-modified-id="Исследование-географии-пользователей-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование географии пользователей</a></span></li></ul></li><li><span><a href="#Маркетинговое-исследование" data-toc-modified-id="Маркетинговое-исследование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинговое исследование</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемость-рекламы" data-toc-modified-id="Анализ-общей-окупаемость-рекламы-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ общей окупаемость рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li></ul></li><li><span><a href="#Итоги-исследования" data-toc-modified-id="Итоги-исследования-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Итоги исследования</a></span></li></ul></div>

# %% [markdown]
# ## Анализ исходных данных

# %% [markdown]
# ### Описание проекта
#
# Несколько прошлых месяцев приложение Procrastinate Pro+ постоянно несет убытки - в привлечение пользователей была вложена куча денег, а толку никакого.
#
# **Цель проекта:** Необходимо разобраться в причинах убытков компании
#
# В распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# **Задачи проекта:**
# 1) Изучить, как люди пользуются продуктом.\
# 2) Выяснить, когда пользователи начинают покупать.\
# 3) Посчитать сколько денег приносит каждый клиент.\
# 4) Расчитать время окупаемости клиента.\
# 5) Выяснить, какие факторы отрицательно влияют на привлечение пользователей.

# %% [markdown]
# ### Загрузка исходных данных

# %%
# импорт необходимых для работы библиотек

# отключаем предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# будем отображать графики прямо в jupyter'e
# %matplotlib inline
import matplotlib.pyplot as plt

#графики в svg выглядят более четкими
# %config InlineBackend.figure_format = 'svg' 

#изменим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 5, 3

import pandas as pd
# увеличиваю число показываемых колонок
pd.set_option('display.max_columns',30)

from datetime import datetime, timedelta
import numpy as np

import seaborn as sns

sns.set_style("darkgrid")

# %%
# Импорт данных о посещениях приложения, покупках и затратах на привлечение
visits, orders, costs = (
    pd.read_csv('visits_info_short.csv'),
    pd.read_csv('orders_info_short.csv'),
    pd.read_csv('costs_info_short.csv'),
)

# %%
# Данные о посещениях приложения
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# #### Описание данных таблицы visits_info_short
# В таблице `visits_log_short` (лог сервера с информацией о посещениях сайта) представлены следующие данные:
#
# * `User Id` — уникальный идентификатор пользователя
# * `Device` — категория устройства пользователя
# * `Session start` — дата и время начала сессии
# * `Session End` — дата и время окончания сессии
# * `Channel` — идентификатор рекламного источника, из которого пришел пользователь
# * `Region` - страна пользователя

# %%
# Данные о заказах пользователей
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# #### Описание данных таблицы orders_info_short
# В таблице `orders_log_short` (информация о заказах) представлены следующие данные:
#
# * `User Id` — уникальный id пользователя, который сделал заказ
# * `Event Dt` — дата и время покупки
# * `Revenue` — выручка

# %%
# Данных о затратах на привлечение
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# #### Описание данных таблицы costs_info_short
# В таблице `costs_short` (информация о затратах на маркетинг) представлены следующие данные:
#
# * `Channel` — идентификатор рекламного источника
# * `Dt` — дата
# * `Costs` — затраты на этот рекламный источник в этот день

# %% [markdown]
# ### Приведение названий столбцов и типов данных к требуемым

# %% [markdown]
# Данные загружены, приведем их виду, удобному для работы.
#
# Приведем названия колонок и формат данных в столбцах каждого из датафреймов к требуемому виду:

# %% [markdown]
# Напишу функцию приведения к нижнему регистру названий колонок датафреймов:

# %%
def registr_lower(df):
    df.columns = [str.lower(col) for col in df.columns]

# %% [markdown]
# #### Преобразования в таблице visits

# %%
# привожу к нижнему регистру
registr_lower(visits)
# переименовываю столбцы, добавляя вместо пробелов нижнее подчеркивание
visits = visits.rename(columns={'user id':'user_id','session start':'session_start','session end':'session_end'})
visits.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# Проверим форматы данных в столбцах:

# %%
# формат данных в столбцах
visits.dtypes
# Out:
# user_id           int64
# region           object
# device           object
# channel          object
# session_start    object
# session_end      object
# dtype: object

# %% [markdown]
# Тип данных в столбцах `session_start` и `session_end` не соответстует datetime.
#
# Приведу формат данных в этих столбцов к datetime

# %%
# привожу тип данных столбцов session_start и session_end к datetime
columns = ['session_start','session_end']

for column in columns:
    visits[column] = pd.to_datetime(visits[column])

# проверяю
visits.dtypes
# Out:
# user_id                   int64
# region                   object
# device                   object
# channel                  object
# session_start    datetime64[ns]
# session_end      datetime64[ns]
# dtype: object

# %% [markdown]
# Преобразование типов прошло успешно

# %% [markdown]
# #### Преобразования в таблице orders

# %%
# привожу к нижнему регистру
registr_lower(orders)
# переименовываю столбцы, добавляя вместо пробелов нижнее подчеркивание
orders = orders.rename(columns={'user id':'user_id','event dt':'event_dt'})
orders.head()
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# Проверим форматы данных в столбцах:

# %%
# формат данных в столбцах
orders.dtypes
# Out:
# user_id       int64
# event_dt     object
# revenue     float64
# dtype: object

# %% [markdown]
# Тип данных в столбце `event_dt` не соответстует datetime.
#
# Приведу формат данных в этиом столбце к datetime

# %%
# привожу тип данных столбца event_dt к datetime
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
# проверяю
orders.dtypes
# Out:
# user_id              int64
# event_dt    datetime64[ns]
# revenue            float64
# dtype: object

# %% [markdown]
# Преобразование типов прошло успешно

# %% [markdown]
# #### Преобразования в таблице costs

# %%
# привожу к нижнему регистру
registr_lower(costs)
costs.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# Проверим форматы данных в столбцах:

# %%
# формат данных в столбцах
costs.dtypes
# Out:
# dt          object
# channel     object
# costs      float64
# dtype: object

# %% [markdown]
# Тип данных в столбце `dt` не соответстует datetime.
#
# Приведу формат данных в этом столбцов к datetime

# %%
# привожу тип данных столбца event_dt к datetime
costs['dt'] = pd.to_datetime(costs['dt'])
# проверяю
costs.dtypes
# Out:
# dt         datetime64[ns]
# channel            object
# costs             float64
# dtype: object

# %% [markdown]
# Преобразование типов прошло успешно

# %% [markdown]
# **Вывод:**
#
# Все названия колонок и типы данных в столбцах приведены к нужным форматам

# %% [markdown]
# ### Проверка на пропущенные значения и дубликаты

# %% [markdown]
# Для каждого из датафреймов проверим, есть ли пропущенные значения в столбцах и дубликаты

# %%
# функция-проверка на дубликаты и пропуски
def duplicates_and_nulls(df):
    nulls = df.isna().sum()
    duplicates = df.duplicated().sum()
    return print(f'''Количество пропусков в датафреме по стобцам:
{nulls}
Количество дубликатов - {duplicates}''')

# %%
# проверка датафрейма visits
duplicates_and_nulls(visits)
# Out:
# Количество пропусков в датафреме по стобцам:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
# Количество дубликатов - 0

# %% [markdown]
# Пропусков и явных дубликатов в visits нет

# %%
# проверка датафрейма orders
duplicates_and_nulls(orders)
# Out:
# Количество пропусков в датафреме по стобцам:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64
# Количество дубликатов - 0

# %% [markdown]
# Пропусков и явных дубликатов в orders нет

# %%
# проверка датафрейма orders
duplicates_and_nulls(costs)
# Out:
# Количество пропусков в датафреме по стобцам:
# dt         0
# channel    0
# costs      0
# dtype: int64
# Количество дубликатов - 0

# %% [markdown]
# Пропусков и явных дубликатов в costs нет

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Напишем функцию для расчета профилей пользователей:

# %%
def get_profiles(visits,orders,ad_costs):
    # сортируем сессии по ID пользователя и дате посещения
    # группируем по ID и находим первые значения session_start, channel, device, region
    # столбец с временем первого посещения назовём first_ts
    # столбец с временем последнего посещения назовём last_ts
    profiles = (
        visits.sort_values(by=['user_id','session_start'])
        .groupby('user_id',as_index=False)
        .agg(
            {
                'session_start':'first',
                'session_end':'last',
                'channel':'first',
                'device':'first',
                'region':'first',
            }
        )
        .rename(columns={'session_start':'first_ts','session_end':'last_ts'})
    )
    
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['dt'] = pd.to_datetime(profiles['dt'])# определяем дату первого посещения
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]') # и первый день месяца, в который это посещение произошло
    
    # создаем признак платящего пользователя
    profiles['payer'] = profiles['user_id'].isin(orders['user_id']) 
    
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt','channel'],as_index=False)
        .agg({'user_id':'nunique'})
        .rename(columns={'user_id':'unique_users'})
    )
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt','channel'], how='left')
    
    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt','channel','acquisition_cost']],
        on=['dt','channel'],
        how='left',
    )
    
    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Также напишем функцию для рачета Retention Rate:

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Теперь напишем функцию для расчета конверсии:

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# А также функцию для расчета LTV и ROI:

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# А также функции для визуализации этих метрик — `filter_data()`, `plot_retention()`, `plot_conversion()` и `plot_ltv_roi()`.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(10, 3))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(15, 8))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# С помощью функции `get_profiles()` получаю профили пользователей

# %%
profiles = get_profiles(visits,orders,costs)
profiles.head()
# Out:
#     user_id            first_ts             last_ts     channel  device  \
# 0    599326 2019-05-07 20:58:57 2019-05-09 08:40:06    FaceBoom     Mac
# 1   4919697 2019-07-09 12:46:07 2019-07-10 23:00:37    FaceBoom  iPhone
# 2   6085896 2019-10-01 09:58:33 2019-10-03 10:44:34     organic  iPhone
# 3  22593348 2019-08-22 21:35:48 2019-08-22 21:52:45  AdNonSense      PC
# 4  31989216 2019-10-02 00:07:44 2019-10-02 00:20:52     YRabbit  iPhone
#
#           region         dt      month  payer  acquisition_cost
# 0  United States 2019-05-07 2019-05-01   True          1.088172
# 1  United States 2019-07-09 2019-07-01  False          1.107237
# 2         France 2019-10-01 2019-10-01  False          0.000000
# 3        Germany 2019-08-22 2019-08-01  False          0.988235
# 4  United States 2019-10-02 2019-10-01  False          0.230769

# %%
profiles.shape
# Out:
# (150008, 10)

# %% [markdown]
# Результат — 150008 пользовательских профилей, в каждом из которых есть данные о дате первого посещения и рекламном источнике, который мотивировал пользователя посетить приложение. Такие данные значительно упрощают дальнейший анализ.
#
# Имея готовые профили пользователей, узнаем количество привлечённых каждым источником посетителей.

# %% [markdown]
# ### Исследование каналов привлечения пользователей

# %%
# Количетсво привлеченных пользователей по источникам привлечения
profiles.groupby('channel').agg({'user_id':'nunique','payer':'mean'}).sort_values(by='payer',ascending=False)
# Out:
#                     user_id     payer
# channel
# FaceBoom              29144  0.122049
# AdNonSense             3880  0.113402
# lambdaMediaAds         2149  0.104700
# TipTop                19561  0.096007
# RocketSuperAds         4448  0.079137
# WahooNetBanner         8553  0.052964
# YRabbit                4312  0.038265
# MediaTornado           4364  0.035747
# LeapBob                8553  0.030633
# OppleCreativeMedia     8605  0.027077
# organic               56439  0.020553

# %% [markdown]
# **Промежуточный вывод:**
#
# Больше всего пользователей пришли из "Органики" и каналов FaceBoom и Tip Top. Аутсайдер - lambdaMediaAds.
# Наибольшая доля платящих пользователей приходится из канала FaceBoom - 12,2%. \
# На втором месте по доли платящих пользователей - AdNonSense - 11,3%, но новых пользователей из этого канала за указаный период пришло мало - всего лишь 3880. Не отстает и lambdaMediaAds - доля платящих почти 10,5%, не смотря на то, что через этот канал привлекалось меньше всего пользователей. \
# На последнем месте по платящим - пользователи, пришедшие из органического трафика.
#
# Возможно стоит пересмотреть каналы привлечения пользователей, т.к. наиболее "качественные" пользователи приходят из аутсайдеров. Изучим этот вопрос в дальнейшем

# %% [markdown]
# Изучим динамику привлечения пользователй по месяцам:

# %% [markdown]
# Напишу функцию рисования графиков в зависимости от признака:

# %%
# функций рисования графиков в зависимости от фичи
def plot_profiles(feature):
    profiles.pivot_table(
        index='dt',
        columns=feature,
        values='user_id', 
        aggfunc='nunique'
    ).plot(grid=True,figsize=(10,5))

    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.xlabel('Месяц')
    plt.ylabel('Кол-во пользователей')
    plt.title(f'Динамика привлечения новых пользователей по {feature}')
    plt.show()

# %% [markdown]
# Использую функцию `plot_profiles()` для отображения динамики привлечения новых пользователей в зависимости от канала привлечения:

# %%
plot_profiles('channel')

# %% [markdown]
# С мая по июнь лидером каналов привлечения является Органика, темпы привлечения через этот канал упали к концу мая.
# Из графика видно, что с июня по ноябрь Органика приносит стабильно в среднем в сутки 250 новых пользователей.
#
# Если говорить о FaceBoom и Tip Top, то данные каналы приносили с июня в среднем 150 и 100 пользователей в день соответственно. По другим каналам привлечения все довольно скудно - менее 50 пользователей в сутки.

# %% [markdown]
# ### Исследование популярности устройств, на которых установлено приложение

# %% [markdown]
# Теперь определим, сколько пользователей заходили на сайт с каждого устройства.

# %%
profiles.groupby('device').agg({'user_id':'nunique','payer':'mean'}).sort_values('user_id',ascending=False)
# Out:
#          user_id     payer
# device
# iPhone     54479  0.062079
# Android    35032  0.058518
# PC         30455  0.050468
# Mac        30042  0.063644

# %% [markdown]
# Больше всего пользователей пользуются приложением на iPhone и Android. iPhone - явный лидер.
#
# Приложениями на PC и Mac пользуются почти одинаковое количество пользователей.\
# Наибольшую долю плятящих составляют поклонники "яблочной продукции" - iPhone и Mac. Доля покупателей 6,2% и 6,4% соответственно.
#
# Аутсайдер по платящим пользователям - PC - только 5% привлеченных пользователей совершили покупку.

# %% [markdown]
# И также посмотрим на динамику привлечения пользователей в зависимости от девайса

# %% [markdown]
# Использую функцию `plot_profiles()` для отображения динамики привлечения новых пользователей в зависимости от устройства, на котором установлено приложение:

# %%
plot_profiles('device')

# %% [markdown]
# Из графика видно, что в середине июня и середине июля имеются провалы по привлечению новых пользователей по всем девайсам.
# В начале осени приложение явно начало пользоваться популярностью, видимо на людей нахлынула осенняя хандра и они, начали скачивать приложение от прокрастинации с надеждой, что оно все-таки поможет.
#
# Приложение на iPhone - явный лидер на всем временном промежутке

# %% [markdown]
# ### Исследование географии пользователей

# %% [markdown]
# Теперь посмотрим на географию пользователей приложения:

# %%
# строю сводную таблицу по региону привлечения
profiles.groupby('region').agg({'user_id':'nunique','payer':'mean'}).sort_values('user_id',ascending=False)
# Out:
#                user_id     payer
# region
# United States   100002  0.069019
# UK               17575  0.039829
# France           17450  0.037994
# Germany          14981  0.041119

# %% [markdown]
# Наибильшую долю всех пользователей составляют пользователи из США, доля покупателей из США также наибольшая - почти 7%.
# На втором месте UK и Франция, в которой доля платящих наименьшая - 3,8%.

# %% [markdown]
# Использую функцию `plot_profiles()` для отображения динамики привлечения новых пользователей в зависимости от региона.

# %%
plot_profiles('region')

# %% [markdown]
# Как и ожидалось, больше всего пользователей в приложении из США. В среднем в сутки из этого региона привлекается примерно 550 новых пользователей

# %% [markdown]
# **Вывод по исследованию:**
#
# - Наибильшую долю всех пользователей составляют пользователи из США, на втором месте UK и Франция. США и Германия дают больше всего платящих пользователей. Доли пользователей, совершивших покупки - 6,9% и 4,1% соответственно.
# - Больше всего пользователей пользуются приложением на iPhone и Android. iPhone - явный лидер. Платящими пользователями чаще всего вляются поклонники "яблочной продукции" - iPhone и Mac. Доля покупателей 6,2% и 6,4% соответственно. Аутсайдер по платящим пользователям - PC - только 5% привлеченных пользователей совершили покупку.
# - Больше всего пользователей пришли из "Органики" и каналов FaceBoom и Tip Top. Аутсайдер - lambdaMediaAds. Наибольшая доля платящих пользователей приходится из канала FaceBoom - 12,2%. На втором месте по доли платящих пользователей - AdNonSense - 11,3%, но новых пользователей из этого канала за указаный период пришло мало - всего лишь 3880. Не отстает и lambdaMediaAds - доля платящих почти 10,5%, не смотря на то, что через этот канал привлекалось меньше всего пользователей. На последнем месте по платящим - пользователи, пришедшие из органического трафика.
#
# **Итог:**
#
# Возможно стоит пересмотреть каналы привлечения пользователей, т.к. наиболее "качественные" пользователи приходят из аутсайдеров. Изучим этот вопрос в дальнейшем.

# %% [markdown]
# ## Маркетинговое исследование

# %% [markdown]
# Посчитаем, сколько компания-разработчик потратила на привлечение пользователей в целом:

# %%
round(costs['costs'].sum(),2)
# Out:
# 105497.3

# %% [markdown]
# А теперь проверим все ли затраты на привлечение попали в профили пользователей, сравним их с затратами из таблицы costs:

# %%
print('''Суммарные затраты в таблице costs: {0}
Cуммарные затраты в профилях {1}'''.format(round(costs['costs'].sum(),2),round(profiles['acquisition_cost'].sum(),2)))
# Out:
# Суммарные затраты в таблице costs: 105497.3
# Cуммарные затраты в профилях 105497.3

# %% [markdown]
# Все затраты на привлечение попали в профили, можно проводить дальнейший анализ

# %% [markdown]
# Посчитаем сколько затрат компания понесла на привлечение пользователей в целом по каждому из каналов привлечения:

# %%
profiles.pivot_table(
    index='channel',
    values='acquisition_cost',
    aggfunc='sum')\
    .sort_values('acquisition_cost',ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %% [markdown]
# **Краткий вывод:**
#
# Деньги на маркетинг в основном "вливали" в канал Tip Top и FaceBoom - двух лидеров по количеству привлеченных кользователей.\
# Как мы заметили ранее, доля качественных (платящих пользователей) канала FaceBoom видимо оправдывает свои затраты (доля платящих пользователей - 12%).\
# По каналу Tip Top возникает вопрос, как к лидеру по затратам, ведь на него потратили почти в 1,5 раза больше, чем на FaceBoom, а статистика по качественным пользователям не самая лучшая - лишь 9,6% (4-ое место).\
#
# Предварительно делаю вывод, что реклама на каналы AdNonSense и lambdaMediaAds окупает свои деньги, ведь они находится на втором и третьем месте соответсвтенно по доли качественных пользователей (платящих). При этом бюджет рекламы небольшой.
#
# Канал привлечения WahooNetBanner только съедает бюджет, привлекая при этом очень мало пользователей, которые почти не покупают (5%).
#
# По остальным затратам на каналы привлечения также есть большие вопросы. Необходимо смотреть окупаемость.

# %% [markdown]
# Теперь выясним, как меняется стоимость привлечения для каждого источника от когорты к когорте. Для этого построим сводную таблицу, в которой названиями строк будут даты привлечения пользователей, названиями столбцов — каналы привлечения, а значениями — средний CAC, и построим по ней график истории изменений.

# %%
# строим график истории изменений CAC по каналам привлечения

profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(9, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# По всем каналам, кроме Tip Top видим стабильную ситуацию от месяца к месяцу.
#
# Бизнес настойчиво вливает деньги лишь в Tip Top, от месяца к месяцу увеличивая бюджет, но, как видим, толку от этого мало.

# %% [markdown]
# Посчитаем сколько в среднем стоило привлечение одного пользователя в разрезе канала привлечения:

# %%
# строим сводную таблицу по удельным затратам на привлечение пользователей
profiles.pivot_table(
    index='channel',
    values='acquisition_cost',
    aggfunc='mean')\
    .sort_values('acquisition_cost',ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %% [markdown]
# Также посчитаю сколько в среднем стоит каждый пользователей пришедший в результате рекламной компании:

# %%
round(profiles['acquisition_cost'].mean(),2)
# Out:
# 0.7

# %% [markdown]
# Ничего удивительного в том, что пользователи, привлекаемые из канала Tip Top самые дорогие - почти 2,8 у.е. Ведь бюджет на канал Tip Top очень большой.\
# Пользователи привлекаемые из каналов FaceBoom и AdNonSense дешевле почти 2,5 раза и еще и покупают чаще.

# %% [markdown]
# **Вывод по маркетингу:**
#
# 1) Рекламный бюджет расходуется сомнительным образом. Самые большие деньги вливаются в канал Tip Top. Привлечение пользователя из этого канала стоит компании 2,8 у.е. По этому каналу возникает вопрос, как к лидеру по затратам, ведь на него потратили почти в 1,5 раза больше, чем на FaceBoom, а статистика по качественным пользователям не самая лучшая - лишь 9,6% (4-ое место).
#
# 2) Доля качественных (платящих пользователей) канала FaceBoom видимо оправдывает свои затраты (доля платящих пользователей - 12%). Стоимость привлечения пользователя из этого канала в 2,5 раза меньше, чем из Tip Top - 1,1 у.е.
#
# 3) Предварительно делаю вывод, что реклама на каналы AdNonSense и lambdaMediaAds окупает свои деньги, ведь они находится на втором и третьем месте соответсвтенно по доли платящих пользователей. При этом бюджет рекламы небольшой.
#
# 4) Канал привлечения WahooNetBanner только съедает бюджет, привлекая при этом очень мало пользователей, которые почти не покупают (5%).\
#
# 5) Средний CAC привлечения пользователя по результатам рекламных компания составляет 1,1 у.е.

# %% [markdown]
# ### Анализ общей окупаемость рекламы

# %% [markdown]
# Для начала оценим общую ситуацию — посмотрим на окупаемость рекламы. Рассчитаем и визуализируем LTV и ROI, вызвав функции `get_ltv()` и `plot_ltv_roi()`.

# %% [markdown]
# Установим момент и горизонт анализа данных. По условию на календаре 1 ноября 2019 года, и зададим недельный горизонт анализа 14 дней.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам можно сделать такие выводы:
# * Реклама не окупается. ROI на конец второй недели не дотягивает до 100%. Судя по динамике ROI пользователей, рентабельность рекламы падает с каждым месяцем.
# * CAC, как мы выяснили ранее не стабилен. Наблюдается значительное увеличение рекламного бюджета от месяца к месяцу. Стоимость привлечения каждого нового пользователя увеличивается с каждым месяцем.
# * На LTV влияет сезонный фактор, или даже недельный фактор, но и этот показатель достаточно стабилен.
# * Возможно, дело как раз в ухудшении качества пользователей. Они привлекаются, затрачивается рекламный бюджет но продажи в приложении не растут

# %% [markdown]
# Чтобы разобраться в причинах, пройдём по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
# смотрим окупаемость с разбивкой по устройствам

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# * Пользователи на PC стабильно лучше окупаются, на втором месте - пользователи, использующие девайсы на Android. Поклонники iPhone и Mac не окупаются от слова совсем. Видимо все деньги ушли на покупку девайсов :)
# * Стоимость привлечения пользователей, использующих Mac и iPhone также существенно выше, чем пользователей на PC или Android
# * По LTV нет явных лидеров. Но есть аутсайдер - пользователи на PC.

# %% [markdown]
# Посмотрим как конвертируются пользователи в покупателей по девайсам:

# %%
# смотрим конверсию с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# И посмотрим как удерживаются платящие и неплатящие пользователи

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Платящие пользователи PC удерживаются лучше других пользователей на других девайсах. С неплатящими все стабильно

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# Теперь посмотрим разбивку по странам

# %%
# смотрим окупаемость с разбивкой по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# * Здесь видим явную проблему с пользователями из США. Хоть они и являются лидерами по LTV, но стоимость привлечения таких пользователей очень высока, что несет за собой полный провал в окупаемости инвестиций на рекламу в этом регионе, причем на всем промежутке времени. ROI в динамике снижается на всем интервале времени.
# * По пользователям из Франции, Германии и Великобритании все стабильно. Они стабильно быстро окупаются на 3-и1 лайфтайм. Затраты на привлечение пользователей из этих регионов также стабильны.
# * LTV всё так же подвержен сезонности, но стабилен по всем устройствам.

# %% [markdown]
# Посмотрим в чем проблема пользователей из США, изучим конверсию пользователей и посмотрим на удержание:

# %%
# смотрим конверсию с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Пользователи из США стабильно лучше конвертируются в платящих, лучше чем в других регионах.
#
# Тогда, возможно, дело в удержании.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# А вот с удержанием пользователей из США явные проблемы.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Теперь проверим источники привлечения (channel). Вероятнее всего, как и предполагалось ранее, на окупаемость влияет неудачная реклама в каком-нибудь одном канале.

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# * А вот они и проблемные каналы привлечения - Tip Top, как и говорилось ранее, самый убыточный изначально канал привлечения пользователей. На втором месте по убыточности - FaceBoom, на третьем - AdNonSense. Затраты на привлечение пользователей по каналу Tip Top растут в геометрической прогрессии, а вот с окупаемостью проблема. Видимо сегмент пользователей совсем не тот в данном канале. Хотя постоянное листание ленты Tip Top явно говорит о Прокрастинации, и казалось бы пользователи должны задуматься, скачать приложение и прекратить прокрастинировать, но вот покупать услуги в приложении эти пользователи явно не хотят, аналогичная причина и у пользователей канала привлечения FaceBoom.
# * Остальные каналы всегда стабильно окупаются. В топе канал - LambdaMediaAds. Маркетинговому отделу нужно обратить свой взор на этот канал и задуматься о привлечении пользователе именно с него. Динакмика LTV у него наивысшая, при этом затраты на привлечение одного нового пользователя не космические.

# %% [markdown]
# Узнаем, в чём причина: в низкой конверсии или низком удержании.
# Посчитаем и визуализируем конверсию, вызвав функции `get_conversion()` и `plot_conversion()`.

# %%
# смотрим конверсию с разбивкой по каналам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# С конверсией по каналам есть явный лидер - FaceBoom. 10% процентов пользователей конвертируются в платящих в первый день и в дальнейшем новых покупок не совершают. Видимо скачивание приложения и платная регистрация - единственная покупка пользователей. Здесь ничего криминального.

# %% [markdown]
# Тогда посмотри на удержание по каналам, видимо причина в нем

# %% [markdown]
# Судя по графикам, пользователи FaceBoom конвертируются очень хорошо, причём постоянно. Видимо, дело в удержании. Вызовем функции `get_retention()` и `plot_retention()`, чтобы рассчитать и отразить на графиках этот показатель.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Удержание платящих пользователей пользователей канала FaceBoom стабильно самое низкое из всех каналов, на втором месте только Органика.

# %% [markdown]
# ## Итоги исследования
# **Причины неэффективности привлечения пользователей:**
#
# * Реклама не окупается. ROI на конец второй недели не дотягивает до 100%. Судя по динамике ROI пользователей, рентабельность рекламы падает с каждым месяцем.
# * CAC, как мы выяснили ранее не стабилен. Наблюдается значительное увеличение рекламного бюджета от месяца к месяцу. Стоимость привлечения каждого нового пользователя увеличивается с каждым месяцем.
# * На LTV влияет сезонный фактор, или даже недельный фактор, но и этот показатель достаточно стабилен.
# * Пользователи на PC стабильно лучше окупаются, на втором месте - пользователи, использующие девайсы на Android. Поклонники iPhone и Mac не окупаются от слова совсем. Видимо все деньги ушли на покупку девайсов :)
# * Стоимость привлечения пользователей, использующих Mac и iPhone также существенно выше, чем пользователей на PC или Android
# * По LTV нет явных лидеров. Но есть аутсайдер - пользователи на PC. Также платящие пользователи PC удерживаются лучше других пользователей на других девайсах.
#
#     Что касается региональной зависимости:
# * Здесь видим явную проблему с пользователями из США. Хоть они и являются лидерами по LTV, но стоимость привлечения таких пользователей очень высока, что несет за собой полный провал в окупаемости инвестиций на рекламу в этом регионе, причем на всем промежутке времени. ROI в динамике снижается на всем интервале времени. Не смотря на провальность инвестиций в регион США, пользователи из США стабильно лучше конвертируются в платящих, лучше чем в других регионах. Проблема в том, что платящие пользователи из США не удерживаются.
#     Основная проблема кроется в следующем:
# * Tip Top - самый убыточный изначально канал привлечения пользователей. На втором месте по убыточности - FaceBoom. Затраты на привлечение пользователей по каналу Tip Top растут в геометрической прогрессии, и не окупаются. Видимо сегмент пользователей совсем не тот в данном канале. Хотя постоянное листание ленты Tip Top явно говорит о Прокрастинации, и казалось бы пользователи должны задуматься, скачать приложение и прекратить прокрастинировать, но вот покупать услуги в приложении эти пользователи явно не хотят, аналогичная причина и у пользователей канала привлечения FaceBoom. Удержание платящих пользователей пользователей канала FaceBoom стабильно самое низкое из всех каналов, на втором месте только Органика.
#
# **Рекомендации для отдела маркетинга для повышения эффективности.**
# * Инвестиции в рекалмный бюджет необходимо пересмотреть в первую очередь по каналам привлечения. Маркетинговому отделу нужно обратить свой взор на каналы YRabbit и LabdaMediaAds и задуматься о привлечении пользователе именно с них. Динакмика LTV у LabdaMediaAds наивысшая, у YRabbit также положительная динамика, при этом бюджет на рекламу окупается сполна и затраты на привлечение одного нового пользователя одни из самых низких.
# * Необходимо при этом учесть, что платящие пользователи из США слабо удерживаются и не окупаются. Стоимость привлечения таких пользователей высокая, но это скорее следствие того, что пользователи из США приходят из канала Tip Top. График затрат напрямую напоминает график стоимсоти привлечения пользователей из канала Tip Top.
# * Маркетинговому отделу необходимо переориентироваться на пользователй Android и PC - девайсов, поскольку пользователи iPhone и Mac не окупается совсем.
